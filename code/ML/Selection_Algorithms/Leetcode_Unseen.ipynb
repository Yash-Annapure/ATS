# %%
import pandas as pd
import pickle

# Load model
print("Loading model from pickle file...")
with open('../Selection_Algorithms/leetcode_model.pkl', 'rb') as f:
    data = pickle.load(f)
    final_model = data['model']
print("Model loaded successfully!\n")


def predict_batch_candidates(csv_path):
    """Predict selection probability for all candidates in CSV file"""
    df_unseen = pd.read_csv(csv_path)
    
    print(f"Loaded {len(df_unseen)} unseen candidates from {csv_path}")
    print("\n" + "="*80)
    
    # CORRECT FEATURES - NO USERNAME!
    features = ['Ranking', 'Reputation', 'Easy_Solved', 'Medium_Solved', 'Hard_Solved']
    X_unseen = df_unseen[features]
    
    predictions = final_model.predict(X_unseen)
    probabilities = final_model.predict_proba(X_unseen)[:, 1] * 100
    
    df_unseen['AI_Decision'] = ['GOOD PICK' if pred == 1 else 'BAD PICK' for pred in predictions]
    df_unseen['Match_Score'] = probabilities.round(2)
    df_unseen = df_unseen.sort_values('Match_Score', ascending=False)
    
    return df_unseen


# Predict all candidates
print("BATCH PREDICTION - ALL CANDIDATES")
print("="*80)

results = predict_batch_candidates('../../Profile_Data/Leetcode_Data_Unseen.csv')

print("\nALL CANDIDATES (Sorted by Match Score):")
print(results[['Username', 'Ranking', 'Hard_Solved', 'AI_Decision', 'Match_Score']].to_string(index=False))

print("\n" + "="*80)
print("SUMMARY:")
print(f"Total Candidates: {len(results)}")
print(f"Good Picks: {len(results[results['AI_Decision'] == 'GOOD PICK'])}")
print(f"Bad Picks: {len(results[results['AI_Decision'] == 'BAD PICK'])}")

results.to_csv('../Shortlisted_candidates/LeetCode_Predictions_Results(Unseen).csv', index=False)
print(f"\nResults saved!")
# Out:
# Loading model from pickle file...
# Model loaded successfully!
#
# BATCH PREDICTION - ALL CANDIDATES
# ================================================================================
# Loaded 101 unseen candidates from ../../Profile_Data/Leetcode_Data_Unseen.csv
#
# ================================================================================
#
# ALL CANDIDATES (Sorted by Match Score):
#             Username  Ranking  Hard_Solved AI_Decision  Match_Score
#         Rayleigh0328     2922        369.0   GOOD PICK        100.0
#      maxcruickshanks    17101        224.0   GOOD PICK        100.0
#               Unwise    24096        208.0   GOOD PICK        100.0
#               tojuna     7391        296.0   GOOD PICK        100.0
#            cheatcode    43110        178.0   GOOD PICK        100.0
#        ghoshashis545    14171        230.0   GOOD PICK        100.0
#              Ajit123    12767        300.0   GOOD PICK        100.0
#              qb_2008    24047        219.0   GOOD PICK        100.0
#             mkawa222      894        540.0   GOOD PICK        100.0
#            Anushk_23    11477        278.0   GOOD PICK        100.0
#       phoenix0knight     4008        339.0   GOOD PICK        100.0
#            kporzycki      749        545.0   GOOD PICK        100.0
#            Bakerston       71        646.0   GOOD PICK        100.0
#              yiqunoy    15266        227.0   GOOD PICK        100.0
#          masteralphi     3254        315.0   GOOD PICK        100.0
#              BetoSCL    27530          NaN   GOOD PICK        100.0
#           Ayush_7219    33219        197.0   GOOD PICK        100.0
#           Ankur_8789     2417        359.0   GOOD PICK        100.0
#           shivamtrix    11423        247.0   GOOD PICK        100.0
#          isparsh_671    15003        257.0   GOOD PICK        100.0
#               edcedc     3153        593.0   GOOD PICK        100.0
#                GCYeh     1406        479.0   GOOD PICK        100.0
#                 Ceay    20296        185.0   GOOD PICK        100.0
#  truongcongthanh2000    23904        218.0   GOOD PICK        100.0
#                 rukt     4758        417.0   GOOD PICK        100.0
#              delphih      557        629.0   GOOD PICK        100.0
#              Rhacoal    18585        218.0   GOOD PICK        100.0
#        anubhav100rao     2992        394.0   GOOD PICK        100.0
#          YoungForest     4085        320.0   GOOD PICK        100.0
#            k_a_r_a_n    11334        294.0   GOOD PICK         99.0
#                 xlx2    30920        228.0   GOOD PICK         99.0
# the_halfblood_prince    41954        208.0   GOOD PICK         98.0
#            zzxzxzzxz    69133        213.0    BAD PICK         13.0
#          vbomedeiros    67669        135.0    BAD PICK         10.0
#         balepavleski   611569         67.0    BAD PICK          2.0
#             zoteline   141062        109.0    BAD PICK          0.0
#           sokolowsky  1702961         13.0    BAD PICK          0.0
#             Dr_Pekka   564460         46.0    BAD PICK          0.0
#             user0927  5000001          0.0    BAD PICK          0.0
#         akash_tiwari  5000001          0.0    BAD PICK          0.0
#            liympanda  2194357         15.0    BAD PICK          0.0
#       brandon_wagner  1766909          2.0    BAD PICK          0.0
#             lichapau  5000001          0.0    BAD PICK          0.0
#          EulerianMoe   817352         46.0    BAD PICK          0.0
#           milind0110   213057         69.0    BAD PICK          0.0
#             ft729495  5000001          0.0    BAD PICK          0.0
#         Hotheadcoder  5000001          0.0    BAD PICK          0.0
#          splintersec  5000001          0.0    BAD PICK          0.0
#          lpalanisamy  5000001          0.0    BAD PICK          0.0
#           lolakapuri  5000001          0.0    BAD PICK          0.0
#           unoptimize  1273981         35.0    BAD PICK          0.0
#               talgoo  4217798          0.0    BAD PICK          0.0
#            shirowing  3362804          0.0    BAD PICK          0.0
#          revutrinadh  5000001          0.0    BAD PICK          0.0
#              al_jabr   303803        101.0    BAD PICK          0.0
#         littlemxrush   915397         36.0    BAD PICK          0.0
#      heenaparveen139  5000001          0.0    BAD PICK          0.0
#            Kap_0eesh   158267         93.0    BAD PICK          0.0
#            VladaMG98  1891230         14.0    BAD PICK          0.0
#         amandeeps007  5000001          0.0    BAD PICK          0.0
#              shinbay   645019         69.0    BAD PICK          0.0
#    i_will_beat_my_iq  2999890         10.0    BAD PICK          0.0
#        bigTeccOrBust  1007323          3.0    BAD PICK          0.0
#     Sacred_Conqueror  2177805         17.0    BAD PICK          0.0
#                 az84  5000001          0.0    BAD PICK          0.0
#          aliparlakci  1485100          0.0    BAD PICK          0.0
#              helihuo  5000001          0.0    BAD PICK          0.0
#               Lowiea  5000001          0.0    BAD PICK          0.0
#       pickleRick8008  1552839         21.0    BAD PICK          0.0
#           Agnimandur   457177         65.0    BAD PICK          0.0
#           aniketneje  4364186          0.0    BAD PICK          0.0
#                xuetu   743926         37.0    BAD PICK          0.0
#                asb76   670944          7.0    BAD PICK          0.0
#        Dominater069L  1477167         17.0    BAD PICK          0.0
#                 cjoa   465646         56.0    BAD PICK          0.0
#           prathee100  5000001          0.0    BAD PICK          0.0
#               Kritzy   628198         32.0    BAD PICK          0.0
#      severalprojects  3916583          1.0    BAD PICK          0.0
#              christ5  1546515          2.0    BAD PICK          0.0
#               tjntsb  1591409         14.0    BAD PICK          0.0
#         chramiyounes  5000001          0.0    BAD PICK          0.0
#               alecjo   821926         22.0    BAD PICK          0.0
#              PRD0507  1166201          4.0    BAD PICK          0.0
#         lucasomee006   155319         93.0    BAD PICK          0.0
#            dream_boy   192160         83.0    BAD PICK          0.0
#           sushuiheng  5000001          0.0    BAD PICK          0.0
#             volialex   223735         55.0    BAD PICK          0.0
#           Abdelaleem   148894         85.0    BAD PICK          0.0
#     CALL_ME_SHINCHAN   348735         45.0    BAD PICK          0.0
#       hayoungsong0_0   493322         62.0    BAD PICK          0.0
#   huanghuangkongkong  5000001          0.0    BAD PICK          0.0
#            roll_no_1    93600        141.0    BAD PICK          0.0
#              slpyguy  5000001          0.0    BAD PICK          0.0
#         yangjinh1995   966822         32.0    BAD PICK          0.0
#        _neelytandel_   274434        119.0    BAD PICK          0.0
#              forbell  5000001          0.0    BAD PICK          0.0
#                 7ty7  1291016         23.0    BAD PICK          0.0
#           KavyaC2001  5000001          0.0    BAD PICK          0.0
#           user7895Zl  5000001          0.0    BAD PICK          0.0
#          shyamsai357  4774327          0.0    BAD PICK          0.0
#            dhruv7888   749142         49.0    BAD PICK          0.0
#
# ================================================================================
# SUMMARY:
# Total Candidates: 101
# Good Picks: 32
# Bad Picks: 69
#
# Results saved!
